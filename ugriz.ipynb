# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
hdu = fits.open('filter_curves.fits')
hdu_u=hdu[1].data
print(type(hdu_u))
hdu_g=hdu[2].data
hdu_r=hdu[3].data
hdu_i=hdu[4].data
hdu_z=hdu[5].data
flux_u=hdu_u.field(1)
print(type(flux_u))
wavelength_u=hdu_u.field(0)
flux_g=hdu_g.field(1)
wavelength_g=hdu_g.field(0)
print(flux_u)
print(flux_u.max())
print(flux_u.min())
print(wavelength_u)
print(wavelength_u.max())
print(wavelength_u.min())
x=np.arange(4130,2980)
x1=wavelength_u
y1=flux_u
#plt.plot(x1,y1,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
def printugriz(ndarray1,ndarray2):
    xx=ndarray1
    yy=ndarray2
    plt.plot(xx,yy,'',color = 'black',label="SPEC",linewidth=0.3)#o-:圆形
#printugriz(wavelength_g,flux_g)
def printugriz1(ii):
    hdu_x=hdu[ii].data
    flux=hdu_x.field(1)
    wavelength=hdu_x.field(0)
    xi=wavelength
    yi=flux
    plt.plot(xi,yi,'',color = 'black',label="SPEC",linewidth=0.3)
for i in range(1,6):
    printugriz1(i)
# Out:
# <class 'astropy.io.fits.fitsrec.FITS_rec'>
# <class 'numpy.ndarray'>
# [0.000e+00 1.000e-04 5.000e-04 1.300e-03 2.600e-03 5.200e-03 9.300e-03
#  1.610e-02 2.400e-02 3.230e-02 4.050e-02 4.850e-02 5.610e-02 6.340e-02
#  7.000e-02 7.560e-02 8.030e-02 8.480e-02 8.830e-02 9.170e-02 9.590e-02
#  1.001e-01 1.029e-01 1.044e-01 1.053e-01 1.063e-01 1.075e-01 1.085e-01
#  1.084e-01 1.064e-01 1.024e-01 9.660e-02 8.870e-02 7.870e-02 6.720e-02
#  5.490e-02 4.130e-02 2.680e-02 1.450e-02 7.500e-03 4.200e-03 2.200e-03
#  1.000e-03 6.000e-04 4.000e-04 2.000e-04 0.000e+00]
# 0.1085
# 0.0
# [2980. 3005. 3030. 3055. 3080. 3105. 3130. 3155. 3180. 3205. 3230. 3255.
#  3280. 3305. 3330. 3355. 3380. 3405. 3430. 3455. 3480. 3505. 3530. 3555.
#  3580. 3605. 3630. 3655. 3680. 3705. 3730. 3755. 3780. 3805. 3830. 3855.
#  3880. 3905. 3930. 3955. 3980. 4005. 4030. 4055. 4080. 4105. 4130.]
# 4130.0
# 2980.0
